# %%
# %sql
create external location if not exists databricks_course_ext_dl1_formula1_incr
url 'abfss://formula1-incr@databrickscoursedldip.dfs.core.windows.net/'
with (Storage credential `databricks-course-sc`)
comment 'External location for the formual1-incr container'

# %%
# %fs ls abfss://formula1-incr@databrickscoursedldip.dfs.core.windows.net/landing

# %%
# %sql
show catalogs

# %%
# %sql
create catalog IF not exists formula1_incr
    managed location 'abfss://formula1-incr@databrickscoursedldip.dfs.core.windows.net/'
    comment 'Catalog for the formual1_incr database'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS formula1_incr.landing;

CREATE SCHEMA IF NOT EXISTS formula1_incr.bronze
        managed location 'abfss://formula1-incr@databrickscoursedldip.dfs.core.windows.net/bronze';

CREATE SCHEMA IF NOT EXISTS formula1_incr.silver
    managed location 'abfss://formula1-incr@databrickscoursedldip.dfs.core.windows.net/silver';

CREATE SCHEMA IF NOT EXISTS formula1_incr.gold
    managed location 'abfss://formula1-incr@databrickscoursedldip.dfs.core.windows.net/gold';

# %%
# %sql
use catalog formula1_incr

# %%
# %sql
show schemas;

# %%
# %sql
CREATE external VOLUME formula1_incr.landing.files
location 'abfss://formula1-incr@databrickscoursedldip.dfs.core.windows.net/landing';

# %%
# %fs ls /Volumes/formula1_incr/landing/files
