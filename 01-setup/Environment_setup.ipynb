# %%
# Create a Volume in Unity Catalog
spark.sql("CREATE SCHEMA IF NOT EXISTS formula1")
spark.sql("CREATE VOLUME IF NOT EXISTS formula1.landing")

# %%
ls "/Volumes/workspace/formula1/landing"

# %%
# %sql
show catalogs

# %%
# %sql
create catalog IF not exists formula1

# %%
# Create catalog
spark.sql("CREATE CATALOG IF NOT EXISTS formula1")

# Use that catalog
spark.sql("USE CATALOG formula1")

# Create all 4 schemas
spark.sql("CREATE SCHEMA IF NOT EXISTS formula1.landing")
spark.sql("CREATE SCHEMA IF NOT EXISTS formula1.bronze")
spark.sql("CREATE SCHEMA IF NOT EXISTS formula1.silver")
spark.sql("CREATE SCHEMA IF NOT EXISTS formula1.gold")

print("All schemas created!")

# %%
# %sql
CREATE VOLUME IF NOT EXISTS formula1.landing.files
